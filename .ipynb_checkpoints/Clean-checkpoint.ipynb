# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("historical_air_quality_2021_en.csv")

# %% [markdown]
# **Clean data**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3415 entries, 0 to 3414
# Data columns (total 21 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Station ID          2622 non-null   float64
#  1   AQI index           2618 non-null   object
#  2   Location            2622 non-null   object
#  3   Station name        2622 non-null   object
#  4   Url                 2622 non-null   object
#  5   Dominent pollutant  2114 non-null   object
#  6   CO                  2615 non-null   object
#  7   Dew                 2263 non-null   float64
#  8   Humidity            2608 non-null   float64
#  9   NO2                 2615 non-null   object
#  10  O3                  2608 non-null   object
#  11  Pressure            2608 non-null   object
#  12  PM10                2583 non-null   object
#  13  PM2.5               2614 non-null   object
#  14  SO2                 2614 non-null   object
#  15  Temperature         2615 non-null   float64
#  16  Wind                2615 non-null   float64
#  17  Data Time S         2622 non-null   object
#  18  Data Time Tz        2622 non-null   object
#  19  Status              2622 non-null   object
#  20  Alert level         2622 non-null   object
# dtypes: float64(5), object(16)
# memory usage: 560.4+ KB

# %%
df.rename(columns={"Station ID":"StationID"},inplace = True)
df.rename(columns={"Station name":"StationName"},inplace = True)
df.rename(columns={"Dominent pollutant":"DominentPollutant"},inplace = True)
df.rename(columns={"Data Time Tz":"DataTimeTz"},inplace = True)
df.rename(columns={"Data Time S":"DataTimeS"},inplace = True)
df.rename(columns={"AQI index":"AQI"},inplace = True)
df.rename(columns={"Alert level":"AlertLevel"},inplace = True)

# %%
df.replace('-', np.nan, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3415 entries, 0 to 3414
# Data columns (total 21 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   StationID          2622 non-null   float64
#  1   AQI                2101 non-null   object
#  2   Location           2622 non-null   object
#  3   StationName        2622 non-null   object
#  4   Url                2622 non-null   object
#  5   DominentPollutant  2114 non-null   object
#  6   CO                 2155 non-null   object
#  7   Dew                2263 non-null   float64
#  8   Humidity           2608 non-null   float64
#  9   NO2                1992 non-null   object
#  10  O3                 1227 non-null   object
#  11  Pressure           2608 non-null   object
#  12  PM10               1888 non-null   object
#  13  PM2.5              2184 non-null   object
#  14  SO2                1261 non-null   object
#  15  Temperature        2615 non-null   float64
#  16  Wind               2615 non-null   float64
#  17  DataTimeS          2622 non-null   object
#  18  DataTimeTz         2622 non-null   object
#  19  Status             2622 non-null   object
#  20  AlertLevel         2622 non-null   object
# dtypes: float64(5), object(16)
# memory usage: 560.4+ KB

# %%
#df.drop(['Url','Status','Location','DataTimeTz','O3','NO2','SO2','CO'],axis ='columns',inplace = True)

# %%
tphcm=df[df.StationID == 8767.0]
tphcm.head()
# Out:
#     StationID     AQI              Location  \
# 0      8767.0  102.00  10.782978,106.700711
# 23     8767.0  122.00  10.782978,106.700711
# 46     8767.0  114.00  10.782978,106.700711
# 69     8767.0   80.00  10.782978,106.700711
# 92     8767.0  137.00  10.782978,106.700711
#
#                                           StationName  \
# 0   Ho Chi Minh City US Consulate, Vietnam (Lãnh s...
# 23  Ho Chi Minh City US Consulate, Vietnam (Lãnh s...
# 46  Ho Chi Minh City US Consulate, Vietnam (Lãnh s...
# 69  Ho Chi Minh City US Consulate, Vietnam (Lãnh s...
# 92  Ho Chi Minh City US Consulate, Vietnam (Lãnh s...
#
#                                                   Url DominentPollutant   CO  \
# 0   https://aqicn.org/city/vietnam/ho-chi-minh-cit...              pm25  NaN
# 23  https://aqicn.org/city/vietnam/ho-chi-minh-cit...              pm25  NaN
# 46  https://aqicn.org/city/vietnam/ho-chi-minh-cit...              pm25  NaN
# 69  https://aqicn.org/city/vietnam/ho-chi-minh-cit...              pm25  NaN
# 92  https://aqicn.org/city/vietnam/ho-chi-minh-cit...              pm25  NaN
#
#     Dew  Humidity  NO2  ...  Pressure PM10   PM2.5  SO2 Temperature  Wind  \
# 0   NaN      83.0  NaN  ...  1,009.00  NaN  102.00  NaN        27.0   3.6
# 23  NaN      56.5  NaN  ...  1,008.50  NaN  122.00  NaN        30.5   2.5
# 46  NaN      49.0  NaN  ...  1,007.00  NaN  114.00  NaN        32.0   1.5
# 69  NaN      74.0  NaN  ...  1,009.00  NaN   80.00  NaN        27.0   4.1
# 92  NaN      62.0  NaN  ...  1,007.00  NaN  137.00  NaN        31.0   5.1
#
#               DataTimeS DataTimeTz  Status AlertLevel
# 0   2021-01-21 19:00:00     +07:00  #NAME?     #NAME?
# 23  2021-01-22 13:00:00     +07:00  #NAME?     #NAME?
# 46  2021-01-23 15:00:00     +07:00  #NAME?     #NAME?
# 69  2021-01-25 19:00:00     +07:00  #NAME?     #NAME?
# 92  2021-01-26 16:00:00     +07:00  #NAME?     #NAME?
#
# [5 rows x 21 columns]

# %%
tphcm.groupby(['DominentPollutant']).count()
#tphcm.groupby(['PM10']).count()
# Out:
#                    StationID  AQI  Location  StationName  Url  CO  Dew  \
# DominentPollutant
# pm25                     114  114       114          114  114   0   99
#
#                    Humidity  NO2  O3  Pressure  PM10  PM2.5  SO2  Temperature  \
# DominentPollutant
# pm25                    114    0   0       114     0    114    0          114
#
#                    Wind  DataTimeS  DataTimeTz  Status  AlertLevel
# DominentPollutant
# pm25                114        114         114     114         114

# %%
new_tphcm = tphcm.drop(['DominentPollutant','PM10','StationName','StationID','PM2.5','Url','Status','Location','DataTimeTz','O3','NO2','SO2','CO'],axis=1)
new_tphcm
# Out:
#          AQI   Dew  Humidity  Pressure  Temperature  Wind  \
# 0     102.00   NaN      83.0  1,009.00         27.0   3.6
# 23    122.00   NaN      56.5  1,008.50         30.5   2.5
# 46    114.00   NaN      49.0  1,007.00         32.0   1.5
# 69     80.00   NaN      74.0  1,009.00         27.0   4.1
# 92    137.00   NaN      62.0  1,007.00         31.0   5.1
# ...      ...   ...       ...       ...          ...   ...
# 2507   97.00  24.0      66.0  1,010.00         31.0   2.8
# 2530   65.00  24.0      66.0  1,008.50         31.0   3.6
# 2553  114.00  25.0      79.0  1,009.00         29.0   1.5
# 2576   89.00  20.5      69.0  1,011.00         26.5   3.0
# 2599   93.00  25.5      85.5  1,006.00         28.0   1.0
#
#                 DataTimeS AlertLevel
# 0     2021-01-21 19:00:00     #NAME?
# 23    2021-01-22 13:00:00     #NAME?
# 46    2021-01-23 15:00:00     #NAME?
# 69    2021-01-25 19:00:00     #NAME?
# 92    2021-01-26 16:00:00     #NAME?
# ...                   ...        ...
# 2507  2021-11-10 10:00:00     #NAME?
# 2530  2021-11-16 12:00:00     #NAME?
# 2553  2021-11-20 09:00:00     #NAME?
# 2576  2021-11-26 09:00:00     #NAME?
# 2599  2021-11-29 14:00:00     #NAME?
#
# [114 rows x 8 columns]

# %%
new_tphcm.drop_duplicates(inplace=True)
new_tphcm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 112 entries, 0 to 2599
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   AQI          112 non-null    object
#  1   Dew          97 non-null     float64
#  2   Humidity     112 non-null    float64
#  3   Pressure     112 non-null    object
#  4   Temperature  112 non-null    float64
#  5   Wind         112 non-null    float64
#  6   DataTimeS    112 non-null    object
#  7   AlertLevel   112 non-null    object
# dtypes: float64(4), object(4)
# memory usage: 7.9+ KB

# %%
new_tphcm.reset_index(drop=True, inplace=True)
# drop true : tránh chỉ mục cũ được thêm vào 1 cột
new_tphcm.head(20)
# Out:
#        AQI   Dew  Humidity  Pressure  Temperature  Wind            DataTimeS  \
# 0   102.00   NaN      83.0  1,009.00         27.0   3.6  2021-01-21 19:00:00
# 1   122.00   NaN      56.5  1,008.50         30.5   2.5  2021-01-22 13:00:00
# 2   114.00   NaN      49.0  1,007.00         32.0   1.5  2021-01-23 15:00:00
# 3    80.00   NaN      74.0  1,009.00         27.0   4.1  2021-01-25 19:00:00
# 4   137.00   NaN      62.0  1,007.00         31.0   5.1  2021-01-26 16:00:00
# 5   117.00   NaN      60.0  1,007.00         30.5   4.6  2021-01-27 15:00:00
# 6    91.00   NaN      34.0  1,009.50         32.5   2.5  2021-01-29 14:00:00
# 7    87.00   NaN      65.0  1,012.00         26.0   2.0  2021-01-30 21:00:00
# 8    59.00   NaN      80.5  1,012.00         25.5   1.2  2021-01-31 23:00:00
# 9    59.00   NaN      69.0  1,012.00         25.0   1.0  2021-02-03 00:00:00
# 10   76.00   NaN      73.0  1,012.50         26.0   1.8  2021-02-03 21:00:00
# 11  137.00   NaN      52.0  1,010.00         31.0   3.0  2021-02-05 14:00:00
# 12   91.00   NaN      65.0  1,007.00         29.0   4.6  2021-02-06 17:00:00
# 13  102.00   NaN      43.0  1,006.00         33.0   2.5  2021-02-09 15:00:00
# 14   63.00   NaN      80.5  1,012.00         24.0   4.8  2021-02-14 20:00:00
# 15   74.00  21.0      62.0  1,010.00         29.0   3.0  2021-02-15 14:00:00
# 16   97.00  16.5      41.5  1,009.50         31.0   1.2  2021-02-16 13:00:00
# 17   74.00  15.0      37.0  1,012.00         31.0   1.5  2021-02-17 12:00:00
# 18   93.00  16.5      42.5  1,013.00         30.5   1.0  2021-02-18 13:00:00
# 19   80.00  19.5      65.0  1,012.00         26.5   3.3  2021-02-20 20:00:00
#
#    AlertLevel
# 0      #NAME?
# 1      #NAME?
# 2      #NAME?
# 3      #NAME?
# 4      #NAME?
# 5      #NAME?
# 6      #NAME?
# 7      #NAME?
# 8      #NAME?
# 9      #NAME?
# 10     #NAME?
# 11     #NAME?
# 12     #NAME?
# 13     #NAME?
# 14     #NAME?
# 15          2
# 16     #NAME?
# 17     #NAME?
# 18     #NAME?
# 19     #NAME?

# %%
new_tphcm.Pressure=new_tphcm.Pressure.apply(lambda x :( x.replace(',','')))

# %%
#new_tphcm.replace(np.nan,'0',inplace=True)
#new_tphcm

# %%
new_tphcm= new_tphcm.astype({'AQI':'float'})
new_tphcm= new_tphcm.astype({'Pressure':'float'})
new_tphcm= new_tphcm.astype({'DataTimeS':'datetime64'})
new_tphcm= new_tphcm.astype({'Dew':'float'})
new_tphcm
# Out:
#        AQI   Dew  Humidity  Pressure  Temperature  Wind           DataTimeS  \
# 0    102.0   NaN      83.0    1009.0         27.0   3.6 2021-01-21 19:00:00
# 1    122.0   NaN      56.5    1008.5         30.5   2.5 2021-01-22 13:00:00
# 2    114.0   NaN      49.0    1007.0         32.0   1.5 2021-01-23 15:00:00
# 3     80.0   NaN      74.0    1009.0         27.0   4.1 2021-01-25 19:00:00
# 4    137.0   NaN      62.0    1007.0         31.0   5.1 2021-01-26 16:00:00
# ..     ...   ...       ...       ...          ...   ...                 ...
# 107   97.0  24.0      66.0    1010.0         31.0   2.8 2021-11-10 10:00:00
# 108   65.0  24.0      66.0    1008.5         31.0   3.6 2021-11-16 12:00:00
# 109  114.0  25.0      79.0    1009.0         29.0   1.5 2021-11-20 09:00:00
# 110   89.0  20.5      69.0    1011.0         26.5   3.0 2021-11-26 09:00:00
# 111   93.0  25.5      85.5    1006.0         28.0   1.0 2021-11-29 14:00:00
#
#     AlertLevel
# 0       #NAME?
# 1       #NAME?
# 2       #NAME?
# 3       #NAME?
# 4       #NAME?
# ..         ...
# 107     #NAME?
# 108     #NAME?
# 109     #NAME?
# 110     #NAME?
# 111     #NAME?
#
# [112 rows x 8 columns]

# %%
#filt = new_tphcm['Dew'] <= 0.1
#new_tphcm.loc[filt]

# %%
new_tphcm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112 entries, 0 to 111
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   AQI          112 non-null    float64
#  1   Dew          97 non-null     float64
#  2   Humidity     112 non-null    float64
#  3   Pressure     112 non-null    float64
#  4   Temperature  112 non-null    float64
#  5   Wind         112 non-null    float64
#  6   DataTimeS    112 non-null    datetime64[ns]
#  7   AlertLevel   112 non-null    object
# dtypes: datetime64[ns](1), float64(6), object(1)
# memory usage: 7.1+ KB

# %%
new_tphcm
# Out:
#        AQI   Dew  Humidity  Pressure  Temperature  Wind           DataTimeS  \
# 0    102.0   NaN      83.0    1009.0         27.0   3.6 2021-01-21 19:00:00
# 1    122.0   NaN      56.5    1008.5         30.5   2.5 2021-01-22 13:00:00
# 2    114.0   NaN      49.0    1007.0         32.0   1.5 2021-01-23 15:00:00
# 3     80.0   NaN      74.0    1009.0         27.0   4.1 2021-01-25 19:00:00
# 4    137.0   NaN      62.0    1007.0         31.0   5.1 2021-01-26 16:00:00
# ..     ...   ...       ...       ...          ...   ...                 ...
# 107   97.0  24.0      66.0    1010.0         31.0   2.8 2021-11-10 10:00:00
# 108   65.0  24.0      66.0    1008.5         31.0   3.6 2021-11-16 12:00:00
# 109  114.0  25.0      79.0    1009.0         29.0   1.5 2021-11-20 09:00:00
# 110   89.0  20.5      69.0    1011.0         26.5   3.0 2021-11-26 09:00:00
# 111   93.0  25.5      85.5    1006.0         28.0   1.0 2021-11-29 14:00:00
#
#     AlertLevel
# 0       #NAME?
# 1       #NAME?
# 2       #NAME?
# 3       #NAME?
# 4       #NAME?
# ..         ...
# 107     #NAME?
# 108     #NAME?
# 109     #NAME?
# 110     #NAME?
# 111     #NAME?
#
# [112 rows x 8 columns]

# %%
def Alert_Level(value):
    if value < 50:
        return "good"
    if 50 <= value < 100:
        return "Moderate"
    elif 100 <= value < 150:
        return "Unhealthy for Sensitive Groups"
    elif 150 <= value < 200:
        return "Unhealthy"
    elif 200 <= value < 300:
        return "Very Unhealthy"
    elif value >= 300:
        return "Hazardous"
 
new_tphcm['AlertLevel'] = new_tphcm['AQI'].map(Alert_Level)

# %%
new_tphcm[['AQI', 'AlertLevel']]
# Out:
#        AQI                      AlertLevel
# 0    102.0  Unhealthy for Sensitive Groups
# 1    122.0  Unhealthy for Sensitive Groups
# 2    114.0  Unhealthy for Sensitive Groups
# 3     80.0                        Moderate
# 4    137.0  Unhealthy for Sensitive Groups
# ..     ...                             ...
# 107   97.0                        Moderate
# 108   65.0                        Moderate
# 109  114.0  Unhealthy for Sensitive Groups
# 110   89.0                        Moderate
# 111   93.0                        Moderate
#
# [112 rows x 2 columns]

# %%
#https://journals.ametsoc.org/view/journals/bams/86/2/bams-86-2-225.xml
new_tphcm['Dew'] = new_tphcm.apply(lambda row : (row['Temperature']-20 + row['Humidity']/5 ),axis=1)
new_tphcm.head(10)
# Out:
#      AQI   Dew  Humidity  Pressure  Temperature  Wind           DataTimeS  \
# 0  102.0  23.6      83.0    1009.0         27.0   3.6 2021-01-21 19:00:00
# 1  122.0  21.8      56.5    1008.5         30.5   2.5 2021-01-22 13:00:00
# 2  114.0  21.8      49.0    1007.0         32.0   1.5 2021-01-23 15:00:00
# 3   80.0  21.8      74.0    1009.0         27.0   4.1 2021-01-25 19:00:00
# 4  137.0  23.4      62.0    1007.0         31.0   5.1 2021-01-26 16:00:00
# 5  117.0  22.5      60.0    1007.0         30.5   4.6 2021-01-27 15:00:00
# 6   91.0  19.3      34.0    1009.5         32.5   2.5 2021-01-29 14:00:00
# 7   87.0  19.0      65.0    1012.0         26.0   2.0 2021-01-30 21:00:00
# 8   59.0  21.6      80.5    1012.0         25.5   1.2 2021-01-31 23:00:00
# 9   59.0  18.8      69.0    1012.0         25.0   1.0 2021-02-03 00:00:00
#
#                        AlertLevel
# 0  Unhealthy for Sensitive Groups
# 1  Unhealthy for Sensitive Groups
# 2  Unhealthy for Sensitive Groups
# 3                        Moderate
# 4  Unhealthy for Sensitive Groups
# 5  Unhealthy for Sensitive Groups
# 6                        Moderate
# 7                        Moderate
# 8                        Moderate
# 9                        Moderate

# %%
new_tphcm['new_date'] = [d.date() for d in new_tphcm['DataTimeS']]
new_tphcm['new_time'] = [d.time() for d in new_tphcm['DataTimeS']]
new_tphcm
# Out:
#        AQI   Dew  Humidity  Pressure  Temperature  Wind           DataTimeS  \
# 0    102.0  23.6      83.0    1009.0         27.0   3.6 2021-01-21 19:00:00
# 1    122.0  21.8      56.5    1008.5         30.5   2.5 2021-01-22 13:00:00
# 2    114.0  21.8      49.0    1007.0         32.0   1.5 2021-01-23 15:00:00
# 3     80.0  21.8      74.0    1009.0         27.0   4.1 2021-01-25 19:00:00
# 4    137.0  23.4      62.0    1007.0         31.0   5.1 2021-01-26 16:00:00
# ..     ...   ...       ...       ...          ...   ...                 ...
# 107   97.0  24.2      66.0    1010.0         31.0   2.8 2021-11-10 10:00:00
# 108   65.0  24.2      66.0    1008.5         31.0   3.6 2021-11-16 12:00:00
# 109  114.0  24.8      79.0    1009.0         29.0   1.5 2021-11-20 09:00:00
# 110   89.0  20.3      69.0    1011.0         26.5   3.0 2021-11-26 09:00:00
# 111   93.0  25.1      85.5    1006.0         28.0   1.0 2021-11-29 14:00:00
#
#                          AlertLevel    new_date  new_time
# 0    Unhealthy for Sensitive Groups  2021-01-21  19:00:00
# 1    Unhealthy for Sensitive Groups  2021-01-22  13:00:00
# 2    Unhealthy for Sensitive Groups  2021-01-23  15:00:00
# 3                          Moderate  2021-01-25  19:00:00
# 4    Unhealthy for Sensitive Groups  2021-01-26  16:00:00
# ..                              ...         ...       ...
# 107                        Moderate  2021-11-10  10:00:00
# 108                        Moderate  2021-11-16  12:00:00
# 109  Unhealthy for Sensitive Groups  2021-11-20  09:00:00
# 110                        Moderate  2021-11-26  09:00:00
# 111                        Moderate  2021-11-29  14:00:00
#
# [112 rows x 10 columns]

# %%
new_tphcm.set_index('DataTimeS', inplace=True)
new_tphcm.head()
# Out:
#                        AQI   Dew  Humidity  Pressure  Temperature  Wind  \
# DataTimeS
# 2021-01-21 19:00:00  102.0  23.6      83.0    1009.0         27.0   3.6
# 2021-01-22 13:00:00  122.0  21.8      56.5    1008.5         30.5   2.5
# 2021-01-23 15:00:00  114.0  21.8      49.0    1007.0         32.0   1.5
# 2021-01-25 19:00:00   80.0  21.8      74.0    1009.0         27.0   4.1
# 2021-01-26 16:00:00  137.0  23.4      62.0    1007.0         31.0   5.1
#
#                                          AlertLevel    new_date  new_time
# DataTimeS
# 2021-01-21 19:00:00  Unhealthy for Sensitive Groups  2021-01-21  19:00:00
# 2021-01-22 13:00:00  Unhealthy for Sensitive Groups  2021-01-22  13:00:00
# 2021-01-23 15:00:00  Unhealthy for Sensitive Groups  2021-01-23  15:00:00
# 2021-01-25 19:00:00                        Moderate  2021-01-25  19:00:00
# 2021-01-26 16:00:00  Unhealthy for Sensitive Groups  2021-01-26  16:00:00

# %%
filt = new_tphcm['AQI'] < 10
new_tphcm.loc[filt,['AQI','Temperature','Humidity','Dew']]
# Out:
#                      AQI  Temperature  Humidity   Dew
# DataTimeS
# 2021-11-04 04:00:00  9.0         28.5      76.0  23.7

# %%
new_tphcm = new_tphcm.astype({'new_time':'string'})
new_tphcm['new_time'].dtype
# Out:
# string[python]

# %%
# lọc theo giờ 
filterday = new_tphcm.loc[(new_tphcm['new_time'] == '04:00:00') ]
filterday
# Out:
#                      AQI   Dew  Humidity  Pressure  Temperature  Wind  \
# DataTimeS
# 2021-11-04 04:00:00  9.0  23.7      76.0    1010.5         28.5   2.0
#
#                     AlertLevel    new_date  new_time
# DataTimeS
# 2021-11-04 04:00:00       good  2021-11-04  04:00:00

# %%
filter16 = new_tphcm.loc[(new_tphcm['new_time'] == '16:00:00') ]
filter16
# Out:
#                        AQI   Dew  Humidity  Pressure  Temperature  Wind  \
# DataTimeS
# 2021-01-26 16:00:00  137.0  23.4      62.0    1007.0         31.0   5.1
# 2021-06-26 16:00:00   50.0  25.2      66.0    1008.0         32.0   3.6
# 2021-10-08 16:00:00   17.0  24.8      76.5    1003.0         29.5   4.6
#
#                                          AlertLevel    new_date  new_time
# DataTimeS
# 2021-01-26 16:00:00  Unhealthy for Sensitive Groups  2021-01-26  16:00:00
# 2021-06-26 16:00:00                        Moderate  2021-06-26  16:00:00
# 2021-10-08 16:00:00                            good  2021-10-08  16:00:00

# %%
new_tphcm.drop(index='2021-10-08 16:00:00',inplace=True)
new_tphcm
# Out:
#                        AQI   Dew  Humidity  Pressure  Temperature  Wind  \
# DataTimeS
# 2021-01-21 19:00:00  102.0  23.6      83.0    1009.0         27.0   3.6
# 2021-01-22 13:00:00  122.0  21.8      56.5    1008.5         30.5   2.5
# 2021-01-23 15:00:00  114.0  21.8      49.0    1007.0         32.0   1.5
# 2021-01-25 19:00:00   80.0  21.8      74.0    1009.0         27.0   4.1
# 2021-01-26 16:00:00  137.0  23.4      62.0    1007.0         31.0   5.1
# ...                    ...   ...       ...       ...          ...   ...
# 2021-11-10 10:00:00   97.0  24.2      66.0    1010.0         31.0   2.8
# 2021-11-16 12:00:00   65.0  24.2      66.0    1008.5         31.0   3.6
# 2021-11-20 09:00:00  114.0  24.8      79.0    1009.0         29.0   1.5
# 2021-11-26 09:00:00   89.0  20.3      69.0    1011.0         26.5   3.0
# 2021-11-29 14:00:00   93.0  25.1      85.5    1006.0         28.0   1.0
#
#                                          AlertLevel    new_date  new_time
# DataTimeS
# 2021-01-21 19:00:00  Unhealthy for Sensitive Groups  2021-01-21  19:00:00
# 2021-01-22 13:00:00  Unhealthy for Sensitive Groups  2021-01-22  13:00:00
# 2021-01-23 15:00:00  Unhealthy for Sensitive Groups  2021-01-23  15:00:00
# 2021-01-25 19:00:00                        Moderate  2021-01-25  19:00:00
# 2021-01-26 16:00:00  Unhealthy for Sensitive Groups  2021-01-26  16:00:00
# ...                                             ...         ...       ...
# 2021-11-10 10:00:00                        Moderate  2021-11-10  10:00:00
# 2021-11-16 12:00:00                        Moderate  2021-11-16  12:00:00
# 2021-11-20 09:00:00  Unhealthy for Sensitive Groups  2021-11-20  09:00:00
# 2021-11-26 09:00:00                        Moderate  2021-11-26  09:00:00
# 2021-11-29 14:00:00                        Moderate  2021-11-29  14:00:00
#
# [111 rows x 9 columns]

# %%
hcm = new_tphcm.loc[(new_tphcm['new_time'] != '04:00:00' )]
hcm
# Out:
#                        AQI   Dew  Humidity  Pressure  Temperature  Wind  \
# DataTimeS
# 2021-01-21 19:00:00  102.0  23.6      83.0    1009.0         27.0   3.6
# 2021-01-22 13:00:00  122.0  21.8      56.5    1008.5         30.5   2.5
# 2021-01-23 15:00:00  114.0  21.8      49.0    1007.0         32.0   1.5
# 2021-01-25 19:00:00   80.0  21.8      74.0    1009.0         27.0   4.1
# 2021-01-26 16:00:00  137.0  23.4      62.0    1007.0         31.0   5.1
# ...                    ...   ...       ...       ...          ...   ...
# 2021-11-10 10:00:00   97.0  24.2      66.0    1010.0         31.0   2.8
# 2021-11-16 12:00:00   65.0  24.2      66.0    1008.5         31.0   3.6
# 2021-11-20 09:00:00  114.0  24.8      79.0    1009.0         29.0   1.5
# 2021-11-26 09:00:00   89.0  20.3      69.0    1011.0         26.5   3.0
# 2021-11-29 14:00:00   93.0  25.1      85.5    1006.0         28.0   1.0
#
#                                          AlertLevel    new_date  new_time
# DataTimeS
# 2021-01-21 19:00:00  Unhealthy for Sensitive Groups  2021-01-21  19:00:00
# 2021-01-22 13:00:00  Unhealthy for Sensitive Groups  2021-01-22  13:00:00
# 2021-01-23 15:00:00  Unhealthy for Sensitive Groups  2021-01-23  15:00:00
# 2021-01-25 19:00:00                        Moderate  2021-01-25  19:00:00
# 2021-01-26 16:00:00  Unhealthy for Sensitive Groups  2021-01-26  16:00:00
# ...                                             ...         ...       ...
# 2021-11-10 10:00:00                        Moderate  2021-11-10  10:00:00
# 2021-11-16 12:00:00                        Moderate  2021-11-16  12:00:00
# 2021-11-20 09:00:00  Unhealthy for Sensitive Groups  2021-11-20  09:00:00
# 2021-11-26 09:00:00                        Moderate  2021-11-26  09:00:00
# 2021-11-29 14:00:00                        Moderate  2021-11-29  14:00:00
#
# [110 rows x 9 columns]

# %%
hcm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 110 entries, 2021-01-21 19:00:00 to 2021-11-29 14:00:00
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   AQI          110 non-null    float64
#  1   Dew          110 non-null    float64
#  2   Humidity     110 non-null    float64
#  3   Pressure     110 non-null    float64
#  4   Temperature  110 non-null    float64
#  5   Wind         110 non-null    float64
#  6   AlertLevel   110 non-null    object
#  7   new_date     110 non-null    object
#  8   new_time     110 non-null    string
# dtypes: float64(6), object(2), string(1)
# memory usage: 8.6+ KB

# %%
hcm1 = hcm.groupby(hcm.index.floor('D')).mean()
hcm1['AQI'].describe()
# Out:
# count    108.000000
# mean      69.550926
# std       27.345226
# min       21.000000
# 25%       50.000000
# 50%       66.250000
# 75%       82.750000
# max      156.000000
# Name: AQI, dtype: float64

# %% [markdown]
# **VISUALIZATION**

# %%
hcm[['AQI']].resample('1D').mean().dropna().plot(figsize=(15,5), kind='line')
# Out:
# <AxesSubplot:xlabel='DataTimeS'>

# %%
hcm[['AQI']].resample('1M').mean().dropna().plot(figsize=(15,5), kind='line')
# Out:
# <AxesSubplot:xlabel='DataTimeS'>

# %%
# AQI theo giờ
sns.swarmplot(data=hcm, x=hcm.index.hour, y='AQI')
# Out:
# <AxesSubplot:xlabel='DataTimeS', ylabel='AQI'>

# %%
# %matplotlib inline
plt.rcParams['figure.figsize'] =  (15,5)
plt.rcParams['font.sans-serif'] = 'Open Sans'
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['text.color'] = '#4c4c4c'
plt.rcParams['axes.labelcolor']= '#4c4c4c'
plt.rcParams['xtick.color'] = '#4c4c4c'
plt.rcParams['ytick.color'] = '#4c4c4c'
plt.rcParams['font.size']=12

# %%
colors = ['purple',  'red', 'orange', 'yellow', 'green']
orders = ['Rất không lành mạnh', 'Không lành mạnh', 'Không lành mạnh với nhóm nhạy cảm', 'Trung Bình', 'Tốt']
colormap = dict(zip(orders, colors))
colormap
# Out:
# {'Rất không lành mạnh': 'purple',
#  'Không lành mạnh': 'red',
#  'Không lành mạnh với nhóm nhạy cảm': 'orange',
#  'Trung Bình': 'yellow',
#  'Tốt': 'green'}

# %%
for_pie=hcm['AlertLevel'].value_counts()
plt.pie(for_pie, 
        labels=['Trung Bình', 'Tốt','Không lành mạnh với nhóm nhạy cảm','Không lành mạnh'],
        colors=['yellow', 'green', 'red', 'orange', 'purple'], autopct='%1.1f%%',startangle=90);
plt.title('AlertLevel TP HCM 2021');
# Out:
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Open Sans
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Open Sans

# %%
# plt.scatter(new_tphcm.index.hour, new_tphcm.AQI);
# new_tphcm['h'] = new_tphcm.index.hour
# new_tphcm['m'] = new_tphcm.index.month
#plt.scatter(new_tphcm.index.hour, new_tphcm.AQI);
# AQI theo ngày
plt.style.use('seaborn-whitegrid')
plt.scatter(hcm.index.hour, hcm.AQI);

# %%
# AQI theo ngày
plt.style.use('seaborn-whitegrid')
plt.scatter(hcm.index.day, hcm.AQI);

# %% [markdown]
# **Correlation AQI**

# %%
# https://reader.elsevier.com/reader/sd/pii/S0160412019323323?token=859D4C1B401BE42D2BAC238E5C460525E1726BF703FCE46BBEDC448F241F1EA8A5022B7D93FE548400741B3CA42466BF&originRegion=us-east-1&originCreation=20221216134738

# %%
hcm.corr()
# Out:
#                   AQI       Dew  Humidity  Pressure  Temperature      Wind
# AQI          1.000000 -0.384137 -0.305495 -0.034064     0.073750 -0.145063
# Dew         -0.384137  1.000000  0.624848 -0.297929     0.026225  0.035722
# Humidity    -0.305495  0.624848  1.000000  0.086600    -0.764091 -0.088125
# Pressure    -0.034064 -0.297929  0.086600  1.000000    -0.357052 -0.360370
# Temperature  0.073750  0.026225 -0.764091 -0.357052     1.000000  0.142350
# Wind        -0.145063  0.035722 -0.088125 -0.360370     0.142350  1.000000

# %%
plot = sns.heatmap(hcm.corr(), cmap="YlGnBu", annot=True)

# %%
hcm.corr()['AQI'].plot.barh()
# Out:
# <AxesSubplot:>

# %%
hcm.corr()['Temperature'].plot.barh()
# Out:
# <AxesSubplot:>

# %%
fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(15,15))
fig.suptitle('abcd')
sns.regplot(x=hcm['Dew'], y=hcm['AQI'], ax=axes[0,0], color='tab:green');
sns.regplot(x=hcm['Humidity'], y=hcm['AQI'], ax=axes[0,1], color='tab:blue');
sns.regplot(x=hcm['Pressure'], y=hcm['AQI'], ax=axes[0,2], color='tab:pink');
sns.regplot(x=hcm['Temperature'], y=hcm['AQI'], ax=axes[1,0], color='tab:brown');
sns.regplot(x=hcm['Wind'], y=hcm['AQI'], ax=axes[1,1],color='tab:red');

# %%
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(12,12))
sns.regplot(x=hcm['Dew'], y=hcm['Temperature'], ax=axes[0,0], color='tab:green');
sns.regplot(x=hcm['Humidity'], y=hcm['Temperature'], ax=axes[0,1], color='tab:blue');
sns.regplot(x=hcm['Pressure'], y=hcm['Temperature'], ax=axes[1,0], color='tab:pink');
sns.regplot(x=hcm['Wind'], y=hcm['Temperature'], ax=axes[1,1],color='tab:red');

# %%
sns.lmplot(x='AQI', y='Dew',z='Temperature' data=hcm)
# Out:
#   Input In [48]
#     sns.lmplot(x='AQI', y='Dew',z='Temperature' data=hcm)
#                                                 ^
# SyntaxError: invalid syntax
